# %%
import chess as ch
import random as rd

class Engine:

    def __init__(self, board, maxDepth, color):
        self.board=board
        self.color=color
        self.maxDepth=maxDepth
    
    def getBestMove(self):
        return self.engine(None, 1)

    def evalFunct(self):
        compt = 0
        #Sums up the material values
        for i in range(64):
            compt+=self.squareResPoints(ch.SQUARES[i])
        compt += self.mateOpportunity() + self.openning() + 0.001*rd.random()
        return compt

    def mateOpportunity(self):
        if (self.board.legal_moves.count()==0):
            if (self.board.turn == self.color):
                return -999
            else:
                return 999
        else:
            return 0

    #to make the engine developp in the first moves
    def openning(self):
        if (self.board.fullmove_number<10):
            if (self.board.turn == self.color):
                return 1/20 * self.board.legal_moves.count()
            else:
                return -1/20 * self.board.legal_moves.count()
        else:
            return 0

    #Takes a square as input and 
    #returns the corresponding Hans Berliner's
    #system value of it's resident
    def squareResPoints(self, square):
        pieceValue = 0
        if(self.board.piece_type_at(square) == ch.PAWN):
            pieceValue = 1
        elif (self.board.piece_type_at(square) == ch.ROOK):
            pieceValue = 5.1
        elif (self.board.piece_type_at(square) == ch.BISHOP):
            pieceValue = 3.33
        elif (self.board.piece_type_at(square) == ch.KNIGHT):
            pieceValue = 3.2
        elif (self.board.piece_type_at(square) == ch.QUEEN):
            pieceValue = 8.8

        if (self.board.color_at(square)!=self.color):
            return -pieceValue
        else:
            return pieceValue

        
    def engine(self, candidate, depth):
        
        #reached max depth of search or no possible moves
        if ( depth == self.maxDepth
        or self.board.legal_moves.count() == 0):
            return self.evalFunct()
        
        else:
            #get list of legal moves of the current position
            moveListe = list(self.board.legal_moves)
            
            #initialise newCandidate
            newCandidate = None
            #(uneven depth means engine's turn)
            if(depth % 2 != 0):
                newCandidate = float("-inf")
            else:
                newCandidate = float("inf")
            
            #analyse board after deeper moves
            for i in moveListe:

                #Play move i
                self.board.push(i)

                #Get value of move i (by exploring the repercussions)
                value = self.engine(newCandidate, depth + 1) 

                #Basic minmax algorithm:
                #if maximizing (engine's turn)
                if(value > newCandidate and depth % 2 != 0):
                    #need to save move played by the engine
                    if (depth == 1):
                        move=i
                    newCandidate = value
                #if minimizing (human player's turn)
                elif(value < newCandidate and depth % 2 == 0):
                    newCandidate = value

                #Alpha-beta prunning cuts: 
                #(if previous move was made by the engine)
                if (candidate != None
                 and value < candidate
                 and depth % 2 == 0):
                    self.board.pop()
                    break
                #(if previous move was made by the human player)
                elif (candidate != None 
                and value > candidate 
                and depth % 2 != 0):
                    self.board.pop()
                    break
                
                #Undo last move
                self.board.pop()

            #Return result
            if (depth>1):
                #eturn value of a move in the tree
                return newCandidate
            else:
                #return the move (only on first move)
                return move





import chess as ch

class Main:

    def __init__(self, board=ch.Board):
        self.board=board

    #play human move
    def playHumanMove(self):
        try:
            print(self.board.legal_moves)
            print("""To undo your last move, type "undo".""")
            #get human move
            play = input("Your move: ")
            if (play=="undo"):
                self.board.pop()
                self.board.pop()
                self.playHumanMove()
                return
            self.board.push_san(play)
        except:
            self.playHumanMove()

    #play engine move
    def playEngineMove(self, maxDepth, color):
        engine = Engine(self.board, maxDepth, color)
        self.board.push(engine.getBestMove())

    #start a game
    def startGame(self):
        #get human player's color
        color=None
        while(color!="b" and color!="w"):
            color = input("""Play as (type "b" or "w"): """)
        maxDepth=None
        while(isinstance(maxDepth, int)==False):
            maxDepth = int(input("""Choose depth: """))
        if color=="b":
            while (self.board.is_checkmate()==False):
                print("The engine is thinking...")
                self.playEngineMove(maxDepth, ch.WHITE)
                print(self.board)
                self.playHumanMove()
                print(self.board)
            print(self.board)
            print(self.board.outcome())    
        elif color=="w":
            while (self.board.is_checkmate()==False):
                print(self.board)
                self.playHumanMove()
                print(self.board)
                print("The engine is thinking...")
                self.playEngineMove(maxDepth, ch.BLACK)
            print(self.board)
            print(self.board.outcome())
        #reset the board
        self.board.reset
        #start another game
        self.startGame()

#create an instance and start a game
newBoard= ch.Board()
game = Main(newBoard)
bruh = game.startGame()
# Out:
# Play as (type "b" or "w"): b
# Choose depth: 4
# The engine is thinking...
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B Q K B N R
# <LegalMoveGenerator at 0x7faf30989040 (Nh6, Nf6, Nc6, Na6, h6, g6, f6, e6, d6, c6, b6, a6, h5, g5, f5, e5, d5, c5, b5, a5)>
# To undo your last move, type "undo".
# Your move: e5
# r n b q k b n r
# p p p p . p p p
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B Q K B N R
# The engine is thinking...
# r n b q k b n r
# p p p p . p p p
# . . . . . . . .
# . . . . p . . Q
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K B N R
# <LegalMoveGenerator at 0x7faf309aca90 (Ne7, Nh6, Nf6, Be7, Bd6, Bc5, Bb4, Ba3, Ke7, Qe7, Qf6, Qg5, Qh4, Nc6, Na6, h6, g6, d6, c6, b6, a6, e4, g5, d5, c5, b5, a5)>
# To undo your last move, type "undo".
# Your move: qf6
# <LegalMoveGenerator at 0x7faf309ac280 (Ne7, Nh6, Nf6, Be7, Bd6, Bc5, Bb4, Ba3, Ke7, Qe7, Qf6, Qg5, Qh4, Nc6, Na6, h6, g6, d6, c6, b6, a6, e4, g5, d5, c5, b5, a5)>
# To undo your last move, type "undo".
# Your move: Qf6
# r n b . k b n r
# p p p p . p p p
# . . . . . q . .
# . . . . p . . Q
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K B N R
# The engine is thinking...
# r n b . k b n r
# p p p p . p p p
# . . . . . q . .
# . . . . p . . .
# . . . . . . . .
# . . . . P . . Q
# P P P P . P P P
# R N B . K B N R
# <LegalMoveGenerator at 0x7faf30989dc0 (Ne7, Nh6, Be7, Bd6, Bc5, Bb4, Ba3, Kd8, Ke7, Nc6, Na6, Qd8, Qe7, Qh6, Qg6, Qe6, Qd6, Qc6, Qb6, Qa6, Qg5, Qf5, Qh4, Qf4, Qf3, Qxf2+, h6, g6, d6, c6, b6, a6, e4, h5, g5, d5, c5, b5, a5)>
# To undo your last move, type "undo".
# Your move: Nc6
# r . b . k b n r
# p p p p . p p p
# . . n . . q . .
# . . . . p . . .
# . . . . . . . .
# . . . . P . . Q
# P P P P . P P P
# R N B . K B N R
# The engine is thinking...
# r . b . k b n r
# p p p p . p p p
# . . n . . q . .
# . B . . p . . .
# . . . . . . . .
# . . . . P . . Q
# P P P P . P P P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309acb20 (Nge7, Nh6, Be7, Bd6, Bc5, Bb4, Ba3, Kd8, Ke7, Rb8, Qd8, Qe7, Qh6, Qg6, Qe6, Qd6, Qg5, Qf5, Qh4, Qf4, Qf3, Qxf2+, Nd8, Nb8, Nce7, Na5, Nd4, Nb4, h6, g6, d6, b6, a6, e4, h5, g5, d5, a5)>
# To undo your last move, type "undo".
# Your move: d6
# r . b . k b n r
# p p p . . p p p
# . . n p . q . .
# . B . . p . . .
# . . . . . . . .
# . . . . P . . Q
# P P P P . P P P
# R N B . K . N R
# The engine is thinking...
# r . b . k b n r
# p p p . . p p p
# . . B p . q . .
# . . . . p . . .
# . . . . . . . .
# . . . . P . . Q
# P P P P . P P P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309ac190 (Kd8, Ke7, Bd7, bxc6)>
# To undo your last move, type "undo".
# Your move: bxc6
# r . b . k b n r
# p . p . . p p p
# . . p p . q . .
# . . . . p . . .
# . . . . . . . .
# . . . . P . . Q
# P P P P . P P P
# R N B . K . N R
# The engine is thinking...
# r . b . k b n r
# p . p . . p p p
# . . p p . q . .
# . . . . p . . Q
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309acf10 (Ne7, Nh6, Be7, Kd8, Ke7, Kd7, Bd7, Bb7, Be6, Ba6, Bf5, Bg4, Bh3, Rb8, Qd8, Qe7, Qh6, Qg6, Qe6, Qg5, Qf5, Qh4, Qf4, Qf3, Qxf2+, h6, g6, a6, d5, c5, e4, g5, a5)>
# To undo your last move, type "undo".
# Your move: Qe6
# r . b . k b n r
# p . p . . p p p
# . . p p q . . .
# . . . . p . . Q
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K . N R
# The engine is thinking...
# r . b . k b n r
# p . p . . p p p
# . . p p q . . .
# . . . . p . Q .
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309ac880 (Ne7, Nh6, Nf6, Be7, Kd7, Bd7, Bb7, Ba6, Rb8, Qe7, Qd7, Qh6, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qh3, Qb3, Qxa2, h6, g6, f6, a6, d5, c5, e4, h5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Ne7
# r . b . k b . r
# p . p . n p p p
# . . p p q . . .
# . . . . p . Q .
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K . N R
# The engine is thinking...
# r . b . k b . r
# p . p . n p p p
# . . p p q . . .
# . . . . p . Q .
# . . . . . . . .
# . . P . P . . .
# P P . P . P P P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309b3790 (Rg8, Kd8, Kd7, Bd7, Bb7, Ba6, Rb8, Ng8, Ng6, Nf5, Nd5, Qd7, Qh6, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qh3, Qb3, Qxa2, h6, g6, f6, a6, d5, c5, e4, h5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Bd7
# r . . . k b . r
# p . p b n p p p
# . . p p q . . .
# . . . . p . Q .
# . . . . . . . .
# . . P . P . . .
# P P . P . P P P
# R N B . K . N R
# The engine is thinking...
# r . . . k b . r
# p . p b n p p p
# . . p p q . . .
# . . . . p . Q .
# . . . . . . . .
# . . P . P . P .
# P P . P . P . P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309ac700 (Rg8, Kd8, Rd8, Rc8, Rb8, Ng8, Nc8, Ng6, Nf5, Nd5, Bc8, Qh6, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qh3, Qb3, Qxa2, O-O-O, h6, g6, f6, a6, d5, c5, e4, h5, f5, a5)>
# To undo your last move, type "undo".
# Your move: h6
# r . . . k b . r
# p . p b n p p .
# . . p p q . . p
# . . . . p . Q .
# . . . . . . . .
# . . P . P . P .
# P P . P . P . P
# R N B . K . N R
# The engine is thinking...
# r . . . k b . r
# p . p b n p p .
# . . p p q . . p
# . . . . p . . Q
# . . . . . . . .
# . . P . P . P .
# P P . P . P . P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309ac520 (Rg8, Rh7, Kd8, Rd8, Rc8, Rb8, Ng8, Nc8, Ng6, Nf5, Nd5, Bc8, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qh3, Qb3, Qxa2, O-O-O, g6, a6, d5, c5, e4, g5, a5)>
# To undo your last move, type "undo".
# Your move: Kd8
# r . . k . b . r
# p . p b n p p .
# . . p p q . . p
# . . . . p . . Q
# . . . . . . . .
# . . P . P . P .
# P P . P . P . P
# R N B . K . N R
# The engine is thinking...
# r . . k . b . r
# p . p b n p p .
# . . p p q . . p
# . . . . p . . Q
# P . . . . . . .
# . . P . P . P .
# . P . P . P . P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309b36d0 (Rg8, Rh7, Ke8, Kc8, Rc8, Rb8, Ng8, Nc8, Ng6, Nf5, Nd5, Be8, Bc8, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qh3, Qb3, Qa2, g6, f6, a6, d5, c5, e4, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Rd8
# <LegalMoveGenerator at 0x7faf309b3700 (Rg8, Rh7, Ke8, Kc8, Rc8, Rb8, Ng8, Nc8, Ng6, Nf5, Nd5, Be8, Bc8, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qh3, Qb3, Qa2, g6, f6, a6, d5, c5, e4, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Rg8
# r . . k . b r .
# p . p b n p p .
# . . p p q . . p
# . . . . p . . Q
# P . . . . . . .
# . . P . P . P .
# . P . P . P . P
# R N B . K . N R
# The engine is thinking...
# r . . k . b r .
# p . p b n p p .
# . . p p q . . p
# . . . . p . . Q
# P P . . . . . .
# . . P . P . P .
# . . . P . P . P
# R N B . K . N R
# <LegalMoveGenerator at 0x7faf309b3e80 (Rh8, Ke8, Kc8, Rc8, Rb8, Nc8, Ng6, Nf5, Nd5, Be8, Bc8, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qh3, Qb3, Qa2, g6, f6, a6, d5, c5, e4, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Rc8
# . . r k . b r .
# p . p b n p p .
# . . p p q . . p
# . . . . p . . Q
# P P . . . . . .
# . . P . P . P .
# . . . P . P . P
# R N B . K . N R
# The engine is thinking...
# . . r k . b r .
# p . p b n p p .
# . . p p q . . p
# . . . . p . . Q
# P P . . . . . .
# . . P . P . P N
# . . . P . P . P
# R N B . K . . R
# <LegalMoveGenerator at 0x7faf309b3f40 (Rh8, Ke8, Rb8, Ra8, Ng6, Nf5, Nd5, Be8, Qg6, Qf6, Qf5, Qd5, Qg4, Qc4, Qxh3, Qb3, Qa2, g6, f6, a6, d5, c5, e4, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Qg6
# . . r k . b r .
# p . p b n p p .
# . . p p . . q p
# . . . . p . . Q
# P P . . . . . .
# . . P . P . P N
# . . . P . P . P
# R N B . K . . R
# The engine is thinking...
# . . r k . b r .
# p . p b n p p .
# . . p p . . q p
# . . . . p . . .
# P P . . . . . Q
# . . P . P . P N
# . . . P . P . P
# R N B . K . . R
# <LegalMoveGenerator at 0x7faf309b3580 (Rh8, Ke8, Rb8, Ra8, Be8, Be6, Bf5, Bg4, Bxh3, Qh7, Qf6, Qe6, Qh5, Qg5, Qf5, Qg4, Qe4, Qxg3, Qd3, Qc2, Qxb1, f6, a6, h5, d5, c5, e4, f5, a5)>
# To undo your last move, type "undo".
# Your move: Qxc2
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . . . . Q
# . . P . P . P N
# . . q P . P . P
# R N B . K . . R
# The engine is thinking...
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . . . . Q
# N . P . P . P N
# . . q P . P . P
# R . B . K . . R
# <LegalMoveGenerator at 0x7faf309b3190 (Rh8, Ke8, Rb8, Ra8, Be8, Be6, Bf5, Bg4, Bxh3, Qh7, Qg6, Qf5, Qe4, Qxa4, Qd3, Qxc3, Qb3, Qxd2+, Qb2, Qa2, Qd1+, Qxc1+, Qb1, g6, f6, a6, h5, d5, c5, e4, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Qb3
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . . . . Q
# N q P . P . P N
# . . . P . P . P
# R . B . K . . R
# The engine is thinking...
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . . . . Q
# N q P . P . P N
# . . . P . P . P
# . R B . K . . R
# <LegalMoveGenerator at 0x7faf309b3130 (Rh8, Ke8, Rb8, Ra8, Be8, Be6, Bf5, Bg4, Bxh3, Qe6, Qd5, Qc4, Qxb4, Qxa4, Qxc3, Qxa3, Qc2, Qb2, Qa2, Qd1+, Qxb1, g6, f6, a6, h5, d5, c5, e4, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Qd5
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . q p . . .
# P P . . . . . Q
# N . P . P . P N
# . . . P . P . P
# . R B . K . . R
# The engine is thinking...
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . q p . . .
# P P . . P . . Q
# N . P . . . P N
# . . . P . P . P
# . R B . K . . R
# <LegalMoveGenerator at 0x7faf2000c160 (Rh8, Ke8, Rb8, Ra8, Be8, Be6, Bf5, Bg4, Bxh3, Qe6, Qc5, Qb5, Qa5, Qxe4+, Qd4, Qc4, Qd3, Qb3, Qxd2+, Qa2, g6, f6, a6, h5, c5, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Qd3
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . P . . Q
# N . P q . . P N
# . . . P . P . P
# . R B . K . . R
# The engine is thinking...
# . . r k . b r .
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . P . . Q
# N . P q . . P .
# . . . P . P . P
# . R B . K . N R
# <LegalMoveGenerator at 0x7faf2000cdf0 (Rh8, Ke8, Rb8, Ra8, Be8, Be6, Bf5, Bg4, Bh3, Qa6, Qd5, Qb5, Qxe4+, Qd4, Qc4, Qxg3, Qf3, Qe3+, Qxc3, Qe2+, Qxd2+, Qc2, Qf1+, Qxb1, g6, f6, a6, h5, d5, c5, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: Rh8
# . . r k . b . r
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . P . . Q
# N . P q . . P .
# . . . P . P . P
# . R B . K . N R
# The engine is thinking...
# . . r k . b . r
# p . p b n p p .
# . . p p . . . p
# . . . . p . . .
# P P . . P . . Q
# N . P q . . P .
# . R . P . P . P
# . . B . K . N R
# <LegalMoveGenerator at 0x7faf2000c3d0 (Rg8, Rh7, Ke8, Rb8, Ra8, Be8, Be6, Bf5, Bg4, Bh3, Qa6, Qd5, Qb5, Qxe4+, Qd4, Qc4, Qxg3, Qf3, Qe3+, Qxc3, Qe2+, Qxd2+, Qc2, Qf1+, Qb1, g6, f6, a6, h5, d5, c5, g5, f5, a5)>
# To undo your last move, type "undo".
# Your move: g5
# . . r k . b . r
# p . p b n p . .
# . . p p . . . p
# . . . . p . p .
# P P . . P . . Q
# N . P q . . P .
# . R . P . P . P
# . . B . K . N R
# The engine is thinking...
# . . r k . b . r
# p . p b n p . .
# . . p p . . . p
# . . . . p . p Q
# P P . . P . . .
# N . P q . . P .
# . R . P . P . P
# . . B . K . N R
# <LegalMoveGenerator at 0x7faf2000c880 (Rg8, Rh7, Bg7, Ke8, Rb8, Ra8, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qa6, Qd5, Qb5, Qxe4+, Qd4, Qc4, Qxg3, Qf3, Qe3+, Qxc3, Qe2+, Qxd2+, Qc2, Qf1+, Qb1, f6, a6, d5, c5, g4, f5, a5)>
# To undo your last move, type "undo".
# Your move: Rh7
# . . r k . b . .
# p . p b n p . r
# . . p p . . . p
# . . . . p . p Q
# P P . . P . . .
# N . P q . . P .
# . R . P . P . P
# . . B . K . N R
# The engine is thinking...
# . . r k . b . .
# p . p b n p . r
# . . p p . . . p
# . . . . p . p Q
# P P . . P . . .
# N . P q . P P .
# . R . P . . . P
# . . B . K . N R
# <LegalMoveGenerator at 0x7faf20008160 (Bg7, Ke8, Rb8, Ra8, Rh8, Rg7, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qa6, Qd5, Qb5, Qxe4+, Qd4, Qc4, Qxf3, Qe3+, Qxc3, Qe2+, Qxd2+, Qc2, Qf1+, Qb1, f6, a6, d5, c5, g4, f5, a5)>
# To undo your last move, type "undo".
# Your move: Bg7
# . . r k . . . .
# p . p b n p b r
# . . p p . . . p
# . . . . p . p Q
# P P . . P . . .
# N . P q . P P .
# . R . P . . . P
# . . B . K . N R
# The engine is thinking...
# . . r k . . . .
# p . p b n Q b r
# . . p p . . . p
# . . . . p . p .
# P P . . P . . .
# N . P q . P P .
# . R . P . . . P
# . . B . K . N R
# <LegalMoveGenerator at 0x7faf20008070 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qa6, Qd5, Qb5, Qxe4+, Qd4, Qc4, Qxf3, Qe3+, Qxc3, Qe2+, Qxd2+, Qc2, Qf1+, Qb1, a6, h5, d5, c5, g4, a5)>
# To undo your last move, type "undo".
# Your move: Qa6
# . . r k . . . .
# p . p b n Q b r
# q . p p . . . p
# . . . . p . p .
# P P . . P . . .
# N . P . . P P .
# . R . P . . . P
# . . B . K . N R
# The engine is thinking...
# . . r k . . . .
# p . p b n Q b r
# q . p p . . . p
# P . . . p . p .
# . P . . P . . .
# N . P . . P P .
# . R . P . . . P
# . . B . K . N R
# <LegalMoveGenerator at 0x7faf2000c130 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qb7, Qb6, Qb5, Qxa5, Qc4, Qd3, Qe2+, Qf1+, h5, d5, c5, g4)>
# To undo your last move, type "undo".
# Your move: Qd3
# . . r k . . . .
# p . p b n Q b r
# . . p p . . . p
# P . . . p . p .
# . P . . P . . .
# N . P q . P P .
# . R . P . . . P
# . . B . K . N R
# The engine is thinking...
# . . r k . . . .
# p . p b n Q b r
# . . p p . . . p
# P . . . p . p .
# . P . . P . . .
# N . P q . P P .
# . R . P N . . P
# . . B . K . . R
# <LegalMoveGenerator at 0x7faf20008850 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qa6, Qd5, Qb5, Qxe4, Qd4, Qc4, Qxf3, Qe3, Qxc3, Qxe2+, Qxd2+, Qc2, Qb1, a6, h5, d5, c5, g4)>
# To undo your last move, type "undo".
# Your move: a6
# . . r k . . . .
# . . p b n Q b r
# p . p p . . . p
# P . . . p . p .
# . P . . P . . .
# N . P q . P P .
# . R . P N . . P
# . . B . K . . R
# The engine is thinking...
# . . r k . . . .
# . . p b n Q b r
# p . p p . . . p
# P . . . p . p .
# . P . . P . . .
# . . P q . P P .
# . R N P N . . P
# . . B . K . . R
# <LegalMoveGenerator at 0x7faf20008cd0 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qd5, Qb5, Qxe4, Qd4, Qc4, Qxf3, Qe3, Qxc3, Qxe2+, Qxd2+, Qxc2, h5, d5, c5, g4)>
# To undo your last move, type "undo".
# Your move: Qb5
# . . r k . . . .
# . . p b n Q b r
# p . p p . . . p
# P q . . p . p .
# . P . . P . . .
# . . P . . P P .
# . R N P N . . P
# . . B . K . . R
# The engine is thinking...
# . . r k . . . .
# . . p b n Q b r
# p . p p . . . p
# P q . . p . p .
# . P P . P . . .
# . . . . . P P .
# . R N P N . . P
# . . B . K . . R
# <LegalMoveGenerator at 0x7faf2000cee0 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qb8, Qb7, Qb6, Qd5, Qc5, Qxa5, Qxc4, Qxb4, Qa4, h5, d5, c5, g4)>
# To undo your last move, type "undo".
# Your move: Qb7
# . . r k . . . .
# . q p b n Q b r
# p . p p . . . p
# P . . . p . p .
# . P P . P . . .
# . . . . . P P .
# . R N P N . . P
# . . B . K . . R
# The engine is thinking...
# . . r k . . . .
# . q p b n Q b r
# p . p p . . . p
# P . . . p . p .
# . P P . P . . .
# . . . . . P P .
# . R N P . . . P
# . . B . K . N R
# <LegalMoveGenerator at 0x7faf20008ca0 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qb8, Qa8, Qa7, Qb6, Qb5, Qxb4, h5, d5, c5, g4)>
# To undo your last move, type "undo".
# Your move: Qa7
# . . r k . . . .
# q . p b n Q b r
# p . p p . . . p
# P . . . p . p .
# . P P . P . . .
# . . . . . P P .
# . R N P . . . P
# . . B . K . N R
# The engine is thinking...
# . . r k . . . .
# q . p b n Q b r
# p . p p . . . p
# P . . . p . p .
# . P P . P . . .
# . . . . . P P .
# . . N P . . . P
# . R B . K . N R
# <LegalMoveGenerator at 0x7faf2000cd60 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qb8, Qa8, Qb7, Qb6, Qc5, Qd4, Qe3+, Qf2+, Qxg1+, h5, d5, c5, g4)>
# To undo your last move, type "undo".
# Your move: c5
# . . r k . . . .
# q . p b n Q b r
# p . . p . . . p
# P . p . p . p .
# . P P . P . . .
# . . . . . P P .
# . . N P . . . P
# . R B . K . N R
# The engine is thinking...
# . . r k . . . .
# q . p b n Q b r
# p . . p . . . p
# P . P . p . p .
# . . P . P . . .
# . . . . . P P .
# . . N P . . . P
# . R B . K . N R
# <LegalMoveGenerator at 0x7faf2000c6a0 (Rb8, Ra8, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nc6, Nf5, Nd5, Be8, Be6, Bc6, Bf5, Bb5, Bg4, Ba4, Bh3, Qb8, Qa8, Qb7, Qb6, Qxc5, dxc5, c6, h5, d5, g4)>
# To undo your last move, type "undo".
# Your move: Qa8
# q . r k . . . .
# . . p b n Q b r
# p . . p . . . p
# P . P . p . p .
# . . P . P . . .
# . . . . . P P .
# . . N P . . . P
# . R B . K . N R
# The engine is thinking...
# q . r k . . . .
# . . p b n Q b r
# p . . P . . . p
# P . . . p . p .
# . . P . P . . .
# . . . . . P P .
# . . N P . . . P
# . R B . K . N R
# <LegalMoveGenerator at 0x7faf20008a60 (Rb8, Qb8, Qb7, Qa7, Qc6, Qd5, Qxe4+, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nc6, Nf5, Nd5, Be8, Be6, Bc6, Bf5, Bb5, Bg4, Ba4, Bh3, cxd6, c6, h5, g4, c5)>
# To undo your last move, type "undo".
# Your move: cxd6
# q . r k . . . .
# . . . b n Q b r
# p . . p . . . p
# P . . . p . p .
# . . P . P . . .
# . . . . . P P .
# . . N P . . . P
# . R B . K . N R
# The engine is thinking...
# q . r k . . . .
# . . . b n Q b r
# p . . p . . . p
# P . . . p . p .
# . . P . P . . .
# . . . . . P P .
# . . N P K . . P
# . R B . . . N R
# <LegalMoveGenerator at 0x7faf2000c790 (Kc7, Rb8, Rc7, Rc6, Rc5, Rxc4, Qb8, Qb7, Qa7, Qc6, Qd5, Qxe4+, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nc6, Nf5, Nd5, Be8, Be6, Bc6, Bf5, Bb5, Bg4, Ba4, Bh3, h5, d5, g4)>
# To undo your last move, type "undo".
# Your move: Qc6
# . . r k . . . .
# . . . b n Q b r
# p . q p . . . p
# P . . . p . p .
# . . P . P . . .
# . . . . . P P .
# . . N P K . . P
# . R B . . . N R
# The engine is thinking...
# . . r k . . . .
# . . . b n Q b r
# p . q p . . . p
# P . . . p . p .
# . N P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# <LegalMoveGenerator at 0x7faf20008a90 (Kc7, Rb8, Ra8, Rc7, Rh8, Bh8, Bf8, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Be6, Bf5, Bg4, Bh3, Qa8, Qc7, Qb7, Qb6, Qd5, Qc5, Qb5, Qxe4+, Qxc4+, Qa4, h5, d5, g4)>
# To undo your last move, type "undo".
# Your move: h5
# . . r k . . . .
# . . . b n Q b r
# p . q p . . . .
# P . . . p . p p
# . N P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# The engine is thinking...
# . . r k . . . .
# . . . b n Q b r
# p . N p . . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# <LegalMoveGenerator at 0x7faf2000c910 (Kc7, Rxc6, Nxc6, Bxc6)>
# To undo your last move, type "undo".
# Your move: bxc6
# <LegalMoveGenerator at 0x7faf2000cca0 (Kc7, Rxc6, Nxc6, Bxc6)>
# To undo your last move, type "undo".
# Your move: Bxc6
# . . r k . . . .
# . . . . n Q b r
# p . b p . . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# The engine is thinking...
# . . r k . . . .
# . . . . n . b r
# p . b p Q . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# <LegalMoveGenerator at 0x7faf200085b0 (Ke8, Kc7, Rb8, Ra8, Rc7, Rh8, Rh6, Bh8, Bf8, Bh6, Bf6, Ng8, Ng6, Nf5, Nd5, Be8, Ba8, Bd7, Bb7, Bd5, Bb5, Bxe4, Ba4, d5, h4, g4)>
# To undo your last move, type "undo".
# Your move: Bf8
# . . r k . b . .
# . . . . n . . r
# p . b p Q . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# The engine is thinking...
# . . r k . b . .
# . . . . n . . r
# p . b Q . . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# <LegalMoveGenerator at 0x7faf2000c5b0 (Ke8, Bd7)>
# To undo your last move, type "undo".
# Your move: Bd7
# . . r k . b . .
# . . . b n . . r
# p . . Q . . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . R B . . . N R
# The engine is thinking...
# . . r k . b . .
# . R . b n . . r
# p . . Q . . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . . B . . . N R
# <LegalMoveGenerator at 0x7faf20008b50 (Bg7, Bh6, Ke8, Rb8, Ra8, Rc7, Rc6, Rc5, Rxc4, Rh8, Rg7, Rf7, Rh6, Ng8, Ng6, Nc6, Nf5, Nd5, h4, g4)>
# To undo your last move, type "undo".
# Your move: Rc6
# . . . k . b . .
# . R . b n . . r
# p . r Q . . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . . B . . . N R
# The engine is thinking...
# . . . k . b . .
# . R . Q n . . r
# p . r . . . . .
# P . . . p . p p
# . . P . P . . .
# . . . . . P P .
# . . . P K . . P
# . . B . . . N R
# <LegalMoveGenerator at 0x7faf2000a0d0 ()>
# To undo your last move, type "undo".

# %%
pip install Chess
